# %% [markdown]
# **A. DE LA LÓGICA A LA DECISIÓN
# Condiciones simples y esctructuras if / else**

# %% [markdown]
# **1.** Complete la condición para mostrar "Mayor de edad" cuando la variable edad sea mayor o igual a 18

# %%
edad = 20
if edad >=18:
  print ("Mayor de edad")
# Out:
# Mayor de edad

# %% [markdown]
# **2.** Completa la estructura para clasificar una temperatura como "Alta" si supera 30 grados y "Normal" en caso contrario

# %%
temperatura = 32
if temperatura > 30:
  print ("Alta")
else:
  print ("Normal")
# Out:
# Alta

# %% [markdown]
# **3.** texto en negritaSin ejecutar, escribe exactamente qué imprimirá el programa

# %%
numero = 7
if numero % 2 ==0:
  print ("Par")
else:
  print ("Impar")

# %% [markdown]
# **Mi respuesta:** Impar

# %% [markdown]
# **B. MÚLTIPLES CONDICIONES
# if / elif / else y orden de evaluación**

# %% [markdown]
# **4.** Agrega las dos expresiones faltantes para clasificar la nota

# %%
nota = 4.2
if nota >= 4.5:
  print ("Excelente")
elif nota >= 4:
  print ("Muy buen desempeño")
elif nota >= 3:
  print ("Aprobado")
else:
  print ("No aprobado")
# Out:
# Muy buen desempeño

# %% [markdown]
# **5.** El programa pretende mostrar "Excelente" para notas de 4.5 o más. Reescribe únicamente el bloque condicional en el orden correcto

# %%
nota = 4.8
if nota >= 4.5:
  print ("Excelente")
elif nota >= 3.0:
  print ("Aprobado")
# Out:
# Excelente

# %% [markdown]
# **6.** Escribe la salida para valor = 12. Después indica cuál condición fue la primera verdadera.

# %%
valor = 12
if valor < 5:
  print ("A")
elif valor < 10:
  print ("B")
elif valor <15:
  print ("C")
else:
  print ("D")
# Out:
# C

# %% [markdown]
# **Mi respuesta:** <5

# %% [markdown]
# **C. OPERADORES LÓGICOS
# Construye condiciones con and, or and not**

# %% [markdown]
# **7.** Completa el operador lógico para permitir acceso solo cuando ambas variables sean verdaderas

# %%
usuario_activo = True
tiene_permiso = True

if usuario_activo and tiene_permiso:
  print ("Acceso permitido")
else:
  print ("Acceso denegado")
# Out:
# Acceso permitido

# %% [markdown]
# **8.** Completa la condición: se permite continuar si existe correo válido o teléfono válido

# %%
correo_valido = False
telefono_valido = True

if correo_valido or telefono_valido:
  print ("Continuar registro")
else:
  print ("Faltan datos de contacto")
# Out:
# Continuar registro

# %% [markdown]
# **9.** Completa la condición usando not para mostrar el mensaje solo si la cuenta NO está bloqueada

# %%
cuenta_bloqueada = False

if not cuenta_bloqueada:
  print ("Puede operar")
# Out:
# Puede operar

# %% [markdown]
# **D. ESTRUCTURA REPETITIVA FOR  Recorrer rangos y controlar iteraciones**

# %% [markdown]
# **10.** Completa range () para imprimir los valores 1, 2, 3, 4 y 5

# %%
for numero in range (1,6):
  print (numero)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# **11.** Completa range () para imprimir 2, 4, 6, 8 y 10

# %%
for numero in range (2,11,2):

  print (numero)
# Out:
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# **12.** Sin ejecutar, determina el valor final de suma

# %%
suma = 0

for i in range (1,4):
  suma = suma + i

print (suma)
# Out:
# 6

# %% [markdown]
# **Mi respuesta:** 6

# %% [markdown]
# **E. ESTRUCTURA REPETITIVA WHILE
# Repetir mientras una condición permanezca verdadera**

# %% [markdown]
# **13.** Completa la condición y la actualización para imprimir los números del 1 al 5

# %%
numero = 1

while numero <6:
  print (numero)
  numero = numero +1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# **14.** El siguiente programa nunca termina. Corrige solo la línea que falta dentro del ciclo

# %%
numero = 1

while numero <=5:
  print (numero)
  numero = numero + 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# **15.** Completa el ciclo para permitir máximo 3 intentos. No modifiques las líneas ya escritas

# %%
intentos = 0
while intentos < 3:
  clave = input ("Ingrese la clave:")
  intentos = intentos + 1

print ("Proceso finalizado")
# Out:
# Ingrese la clave:000
# Ingrese la clave:001
# Ingrese la clave:002
# Proceso finalizado

# %% [markdown]
# **F. ELEGIR Y COMBINAR ESTRUCTURAS
# for + if, while + condición y razonamiento sobre flujo**

# %% [markdown]
# **16. Escribe la estructura que elegirías en cada situación** ¿for o while?
# ![Captura de pantalla 2026-08-13 195255.png](data:image/png;base64,...)

# %% [markdown]
# **Mi respuesta:**
#
# A. for
#
# B. While
#
# C. for
#
# D. While

# %% [markdown]
# **17.** Completa el programa para recorrer del 1 al 12 y mostrar únicamente los múltiplos de 3

# %%
for numero in range (1,13):
  if numero % 3==0:
    print (numero)
# Out:
# 3
# 6
# 9
# 12

# %% [markdown]
# **18.** Escribe todas las líneas que producirá el programa

# %%
for numero in range (1,8):
  if numero < 3:
    print (numero, "A")
  elif numero < 6:
    print (numero, "B")
  else:
    print (numero, "C")
# Out:
# 1 A
# 2 A
# 3 B
# 4 B
# 5 B
# 6 C
# 7 C

# %% [markdown]
# **Mi respuesta:**
#
# 1 A
#
# 2 A
#
# 3 B
#
# 4 B
#
# 5 B
#
# 6 C
#
# 7 C

# %% [markdown]
# **G. DEL PSEUDOCÓDIGO A PYTHON
# Conserva la lógica y cambia la representación**

# %% [markdown]
# **19.** Completa el código Python para que represente exactamente el pseudocódigo mostrado

# %%
nota = float (input("Nota: "))
if nota >= 3.0:
  print ("Aprobado")
else:
  print ("No aprobado")
# Out:
# Nota: 2
# No aprobado

# %% [markdown]
# **20.** Completa el programa python equivalente al pseudocódigo

# %%
for i in range (1,6):
  print (i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# **FIN**

# %% [markdown]
# **RETO INTEGRADOR**
#
# Completa todos los espacios. Antes de ejecutar, prueba mentalmente tu solución con los valores: 15, 18, 22, 25 y 30

# %%
# El programa debe solicitar 5 temperaturas
# Para cada una debe mostrar:
# "Baja" si t < 18
# "Normal" si 18 <= t <= 25
# "Alta" si t >25

for t in range (5):
  t = float (input ("Temperatura: "))

  if t <18:
    print ("Baja")
  elif t >=18 and t<=25:
    print ("Normal")
  else:
    print ("Alta")
# Out:
# Temperatura: 18
# Normal
# Temperatura: 15
# Baja
# Temperatura: 22
# Normal
# Temperatura: 25
# Normal
# Temperatura: 30
# Alta

# %% [markdown]
# **Autoevaluación rápida:**
# 1. ¿Puedo explicar cuándo usar if, elif y else?
# 2. ¿Puedo distinguir cuándo conviene for y cuándo while?
# 3. ¿Puedo identificar el riesgo de un ciclo infinito?
# 4. ¿Puedo traducir una decisión o repetición desde pseudocódigo a Python?

# %% [markdown]
# **Mis respuestas**
#
# 1. Si, if es "sí tal cosa" como primera condición...elif es un "sino"...y  else es para los demás casos.
#
# 2. For cuando conozco cuantas veces se va a iterar y while cuando no conozco el número exacto de iteraciones...for para rangos y secuencias y while cuando depende de una condición
#
# 3. Sí, que el programa nunca va a terminar y al ser infinito puede provocar un error computacional y reiniciar/trabar el progreso (me pasó)
#
# 4. Sí, mientras se usen las condiciones y estructuras correctas el código en python puede entender lo que el pseudocódigo quiere traducir

# %% [markdown]
# **Ahora  si...FIN**
