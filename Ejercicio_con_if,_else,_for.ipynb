# %%
precio = 100000
iva = precio *0.19
total = precio + iva
print (total)
# Out:
# 119000.0

# %%
if total > 100000:
  print ("Compra de alto valor")
else:
  print ("Compra de bajo valor")
# Out:
# Compra de alto valor

# %%
for i in range (5):
  print (i)
# Out:
# 0
# 1
# 2
# 3
# 4
