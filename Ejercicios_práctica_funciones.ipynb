# %% [markdown]
# **Ejercicios práctica funciones**

# %% [markdown]
# **1.** Complete la palabra clave que define una función

# %%
def saludar ():
  print("Hola")

saludar()
# Out:
# Hola

# %% [markdown]
# **2.** Complete la línea que ejecuta la función ya definida

# %%
def bienvenida ():
  print("Bienvenida al curso")

bienvenida()
# Out:
# Bienvenida al curso

# %% [markdown]
# **3.** Sin ejecutar, determine en qué orden aparecen los mensajes

# %%
def uno():
  print("A")

print("B")
uno()
print("C")
# Out:
# B
# A
# C

# %% [markdown]
# **Mi respuesta:**
#
# B
#
# A
#
# C

# %% [markdown]
# **4.** El programa falla porque la función se llama antes de existir. Reescriba las líneas en el orden correcto

# %%
def saludar(nombre):
  print("Hola,", nombre)

saludar("Ana")
# Out:
# Hola, Ana

# %% [markdown]
# **5.** Complete el parámetro que recibe la función

# %%
def saludar (nombre):
  print("Hola,", nombre)

saludar("Ana")
# Out:
# Hola, Ana

# %% [markdown]
# **6.** Llame 3 veces a la misma función, cada vez con un precio distinto

# %%
def con_iva(precio):
  return precio * 1.19

print(con_iva(20000))
print(con_iva(85000))
print(con_iva(150000))
# Out:
# 23800.0
# 101150.0
# 178500.0

# %% [markdown]
# **7.** Complete los dos parámetros que la función necesita

# %%
def area(base, altura):
  return base * altura

print(area(3, 4))
# Out:
# 12

# %% [markdown]
# **8.** Complete los argumentos para obtener exactamente el resultado indicado

# %%
def area(base, altura):
  return base * altura

print(area(5, 5))
# Out:
# 25

# %% [markdown]
# **9.** Observe la definición y la llamada, y distinga cada uno de los dos nombres

# %%
def doble(n):
  return n * 2

resultado = (doble(5))

# %% [markdown]
# **10.** Complete la llamada para que se imprima: Ana 20 Bogota

# %%
def perfil(nombre, edad, ciudad):
  print(nombre, edad, ciudad)

perfil("Ana", 20, "Bogota")
# Out:
# Ana 20 Bogota

# %% [markdown]
# **11.** Complete los nombres de los parámetros para que el orden deje de importar

# %%
def perfil(nombre, edad, ciudad):
  print(nombre, edad, ciudad)

perfil(edad=20, nombre="Ana", ciudad="Bogota")
# Out:
# Ana 20 Bogota

# %% [markdown]
# **12.** Complete el valor por defecto del parámetro saludo

# %%
def saludar(nombre, saludo="Hola"):
  print(saludo, nombre)

saludar("Ana")
# Out:
# Hola Ana

# %% [markdown]
# **13.** Complete la palabra clave que entrega el resultado

# %%
def doble(n):
  return n * 2

print(doble(5))
# Out:
# 10

# %% [markdown]
# **14.** Complete la llamada para guardar el resultado y operar con él

# %%
def doble(n):
  return n * 2

resultado = doble(6)
print(resultado + 1)
# Out:
# 13

# %% [markdown]
# **15.** Sin ejecutar, determine qué imprimen las dos últimas líneas

# %%
def saludo(nombre):
  print("Hola,", nombre)

x = saludo("Ana")
print(x)
# Out:
# Hola, Ana
# None

# %% [markdown]
# **16.** La suma falla porque la función no devuelve nada. Escriba la versión corregida de la función

# %%
def doble(n):
  return n * 2

total = doble(5) + 3
print(total)
# Out:
# 13

# %% [markdown]
# **17.** Complete la instrucción que devuelve el segundo resultado

# %%
def signo(n):
  if n < 0:
    return "negativo"
  else:
    return "positivo"

print(signo(-4))
print(signo(7))
# Out:
# negativo
# positivo

# %% [markdown]
# **18.** Complete la función que calcula el promedio de una lista de notas

# %%
def promedio(notas):
  total = 0
  for n in notas:
    total = total + n
  return total / len(notas)

print(promedio([3.5, 4.2, 2.8]))
# Out:
# 3.5

# %% [markdown]
# **19.** Sin ejecutar, determine qué imprime cada una de las dos últimas líneas

# %%
mensaje = "global"

def prueba():
  mensaje = "local"
  print(mensaje)

prueba()
print(mensaje)
# Out:
# local
# global

# %% [markdown]
# **20.** **Reto integrador**
#
# Complete el programa que calcula el promedio de un estudiante y muestra si aprueba, usando dos funciones

# %%
def promedio(notas):
  total = 0
  for n in notas:
    total = total + n
  return total / len(notas)

def reporte(nombre, notas):
  prom = promedio(notas)
  print(nombre, round(prom, 2))
  if prom >= 3.0:
    print("Aprobado")
  else:
    print("No aprobado")

reporte("Laura", [3.5, 4.2, 2.8])
# Out:
# Laura 3.5
# Aprobado
